# %%
! ./train_local.sh keras-test

# %%
! ./serve_local.sh keras-test
# Out:
# Starting the inference server with 48 workers.
# [2019-04-10 16:13:45 +0000] [11] [INFO] Starting gunicorn 19.9.0
# [2019-04-10 16:13:45 +0000] [11] [INFO] Listening at: unix:/tmp/gunicorn.sock (11)
# [2019-04-10 16:13:45 +0000] [11] [INFO] Using worker: gevent
# [2019-04-10 16:13:45 +0000] [16] [INFO] Booting worker with pid: 16
# [2019-04-10 16:13:45 +0000] [17] [INFO] Booting worker with pid: 17
# [2019-04-10 16:13:45 +0000] [19] [INFO] Booting worker with pid: 19
# [2019-04-10 16:13:45 +0000] [67] [INFO] Booting worker with pid: 67
# [2019-04-10 16:13:45 +0000] [70] [INFO] Booting worker with pid: 70
# [2019-04-10 16:13:45 +0000] [166] [INFO] Booting worker with pid: 166
# [2019-04-10 16:13:45 +0000] [165] [INFO] Booting worker with pid: 165
# Using TensorFlow backend.
# [2019-04-10 16:13:45 +0000] [167] [INFO] Booting worker with pid: 167
# Using TensorFlow backend.
# [2019-04-10 16:13:45 +0000] [168] [INFO] Booting worker with pid: 168
# Using TensorFlow backend.
# ...
